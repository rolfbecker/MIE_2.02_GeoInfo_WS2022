# %% [markdown]
# # NRW Groundwater Data - OpenHygrisC
#
# OpenHygrisC Data: https://www.opengeodata.nrw.de/produkte/umwelt_klima/wasser/grundwasser/hygrisc/
#
# Download gw station data: https://www.opengeodata.nrw.de/produkte/umwelt_klima/wasser/grundwasser/hygrisc/OpenHygrisC_gw-messstellen-messwerte_EPSG25832_CSV.zip

# %%
import pandas as pd
import os

# %%
datapath = r"../data/original/OpenHygrisC_gw-messstellen-messwerte_EPSG25832_CSV/"
gw_station_fname = r"opendata.gw_messstelle.csv"
gw_station_pfname = datapath + "/" +  gw_station_fname
print(gw_station_pfname)
# Out:
# ../data/original/OpenHygrisC_gw-messstellen-messwerte_EPSG25832_CSV//opendata.gw_messstelle.csv

# %%
os.listdir(datapath)
# Out:
# ['Hinweise zu den bereitgestellten Grundwasserdaten.pdf',
#  'katalog_gemeinde.csv',
#  'katalog_stoff.csv',
#  'opendata.gw_chemischer_messwert.csv',
#  'opendata.gw_messstelle.csv']

# %%
df = gw_station_df = pd.read_csv(gw_station_pfname, sep = ";", index_col=["messstelle_id"] )

# %%
idx_coords_missing = (df["e32"].str.len() < 6) \
| (df["e32"].isnull() == True)
idx_is_numeric = (gw_station_df["e32"].str.isnumeric() == True) # is it integer?
# idx_is_not_numeric = ~idx_is_numeric # non-integers
idx_100m_prec = ~idx_is_numeric & ~idx_coords_missing

# %%
N_100m_prec = idx_100m_prec.value_counts()[True]

# %%
N_coords_missing = idx_coords_missing.value_counts()[True]

# %%
N_is_numeric = idx_is_numeric.value_counts()[True]

# %%
assert df.shape[0] == N_is_numeric + N_100m_prec + N_coords_missing, \
"Error: Some values not caught"

# %%
gw_station_df.loc[idx_is_numeric,"genau"] = 1
gw_station_df.loc[idx_100m_prec,"genau"] = 100
gw_station_df.loc[idx_coords_missing,"genau"] = -999

# %%
# ["e32"] -> number -> ["e32num"]
gw_station_df.loc[idx_is_numeric, "n32num"] \
= gw_station_df.loc [idx_is_numeric, "n32"].astype("float") 
gw_station_df.loc[idx_100m_prec, "n32num"] \
= (gw_station_df.loc[idx_100m_prec, "n32"].str[:-2]+"50").astype("float") 
gw_station_df.loc[idx_coords_missing, "n32num"] = -999

# %%
# ["e32"] -> number -> ["e32num"]
gw_station_df.loc[idx_is_numeric, "e32num"] \
= gw_station_df.loc [idx_is_numeric, "e32"].astype("float") 
gw_station_df.loc[idx_100m_prec, "e32num"] \
= (gw_station_df.loc[idx_100m_prec, "e32"].str[:-2]+"50").astype("float") 
gw_station_df.loc[idx_coords_missing, "e32num"] = -999

# %%
gw_station_df.loc[idx_coords_missing,["n32","n32num", "genau"]]
# Out:
#                n32  n32num  genau
# messstelle_id
# 118820000       xx  -999.0 -999.0
# 47202002        xx  -999.0 -999.0
# 118840009       xx  -999.0 -999.0
# 118260005       xx  -999.0 -999.0
# 68013504        xx  -999.0 -999.0
# 68012007        xx  -999.0 -999.0
# 47247101        xx  -999.0 -999.0
# 68013401        xx  -999.0 -999.0
# 118880007       xx  -999.0 -999.0
# 47299009        xx  -999.0 -999.0
# 118550007       xx  -999.0 -999.0
# 118650002       xx  -999.0 -999.0
# 68013206        xx  -999.0 -999.0
# 118010001       xx  -999.0 -999.0
# 47199003        xx  -999.0 -999.0
# 47200005        xx  -999.0 -999.0
# 36446518        xx  -999.0 -999.0
# 118620009       xx  -999.0 -999.0
# 79921802       NaN  -999.0 -999.0
# 68013607        xx  -999.0 -999.0
# 47039000        xx  -999.0 -999.0
# 59621035        xx  -999.0 -999.0
# 118871900       xx  -999.0 -999.0
# 129700800       xx  -999.0 -999.0
# 118810005       xx  -999.0 -999.0
# 118020006       xx  -999.0 -999.0
# 68013103        xx  -999.0 -999.0
# 36487600        xx  -999.0 -999.0
# 68011003        xx  -999.0 -999.0
# 68013309        xx  -999.0 -999.0

# %%
gw_station_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71120 entries, 32505929 to 46201920
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   sl_nr                         71120 non-null  int64
#  1   name                          71120 non-null  object
#  2   e32                           71119 non-null  object
#  3   n32                           71119 non-null  object
#  4   gw_stockwerk                  54186 non-null  float64
#  5   grundstueck                   71120 non-null  object
#  6   gemeinde_id                   71090 non-null  object
#  7   gwhorizont_id                 28424 non-null  object
#  8   gwhorizont                    28424 non-null  object
#  9   gwleiter_id                   2690 non-null   object
#  10  gwleiter                      2690 non-null   object
#  11  einrichtungsgrund             71120 non-null  object
#  12  gwk_lage_auf_id               70486 non-null  object
#  13  gwk_lage_id                   70486 non-null  object
#  14  gwk_monitoring_auf_id         70735 non-null  object
#  15  gwk_monitoring_id             70735 non-null  object
#  16  messprogramm                  16907 non-null  object
#  17  turnus_wasserstand            67710 non-null  object
#  18  freigabe_wstd                 71120 non-null  object
#  19  freigabe_chemie               71120 non-null  object
#  20  freigabe_lage                 71120 non-null  object
#  21  wasserstandsmessstelle        71120 non-null  object
#  22  guetemessstelle               71120 non-null  object
#  23  im_wrrl_messnetz_chemie       71120 non-null  object
#  24  im_wrrl_messnetz_wasserstand  71120 non-null  object
#  25  messstellenart                71120 non-null  object
#  26  wasserart                     16907 non-null  object
#  27  labor                         16907 non-null  object
#  28  beobachtung_wasserstand       68165 non-null  object
#  29  eigentuemer                   45635 non-null  object
#  30  betreiber                     45129 non-null  object
#  31  filterlaenge_cm               38356 non-null  float64
#  32  sumpfrohrlaenge_cm            32201 non-null  float64
#  33  ausbaudurchmesser_mm          43278 non-null  float64
#  34  historischer_ruhe_wsp         792 non-null    float64
#  35  einbaulaenge_cm               59287 non-null  float64
#  36  oberkante_filter_cm           59287 non-null  float64
#  37  unterkante_filter_cm          59287 non-null  float64
#  38  genau                         71120 non-null  float64
#  39  n32num                        71120 non-null  float64
#  40  e32num                        71120 non-null  float64
# dtypes: float64(11), int64(1), object(29)
# memory usage: 22.8+ MB

# %%
# Correct installation bug ocuuring when using OSGeo4W
import os
proj_lib = os.environ['proj_lib']
print(proj_lib)
conda_prefix = os.environ['conda_prefix']
os.environ['proj_lib'] = conda_prefix + r"\Library\share\proj"
proj_lib = os.environ['proj_lib']
print(proj_lib)
# Out:
# C:\OSGeo4W64\share\proj
# C:\Users\rb\Anaconda3\envs\geo\Library\share\proj

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
idx = gw_station_df["genau"] > 0

# %%
df2 = gw_station_df[idx]
# gw_station_df.loc[idx,["e32","n32","e32num","n32num","genau"]]

# %%
df2.head()
# Out:
#                sl_nr                 name     e32      n32  gw_stockwerk  \
# messstelle_id
# 32505929       67530  UWB-Ddorf 01285      343064  5678019           1.0
# 10446746       51044  60GP012303           292077  5645349           NaN
# 87005323       51070  58BP024606           287141  5684635           NaN
# 80000290       68442  Krinsend 0079 neu    309490  5678060           1.0
# 86583852       68518  WG102GM93-3          316741  5680237           NaN
#
#               grundstueck gemeinde_id gwhorizont_id      gwhorizont  \
# messstelle_id
# 32505929                     05111000           NaN             NaN
# 10446746           privat    NL000882             5  Zwischenmittel
# 87005323           privat    NL001640            6D  Neurather Sand
# 80000290                     05166024           NaN             NaN
# 86583852           privat    05166032           NaN             NaN
#
#               gwleiter_id  ... filterlaenge_cm sumpfrohrlaenge_cm  \
# messstelle_id              ...
# 32505929              NaN  ...             NaN                NaN
# 10446746              NaN  ...           200.0                NaN
# 87005323              NaN  ...           500.0              300.0
# 80000290              NaN  ...             NaN                NaN
# 86583852              NaN  ...           200.0                NaN
#
#               ausbaudurchmesser_mm historischer_ruhe_wsp einbaulaenge_cm  \
# messstelle_id
# 32505929                       NaN                   NaN             NaN
# 10446746                       NaN                   NaN         16893.0
# 87005323                       NaN                   NaN         32667.0
# 80000290                       NaN                   NaN          1517.0
# 86583852                      80.0                   NaN          5400.0
#
#               oberkante_filter_cm unterkante_filter_cm genau     n32num  \
# messstelle_id
# 32505929                      NaN                  NaN   1.0  5678019.0
# 10446746                  -3333.0              -3533.0   1.0  5645349.0
# 87005323                 -29083.0             -29583.0   1.0  5684635.0
# 80000290                   4832.0               4832.0   1.0  5678060.0
# 86583852                   1413.0               1213.0   1.0  5680237.0
#
#                  e32num
# messstelle_id
# 32505929       343064.0
# 10446746       292077.0
# 87005323       287141.0
# 80000290       309490.0
# 86583852       316741.0
#
# [5 rows x 41 columns]

# %%
gdf = gpd.GeoDataFrame(df2, \
                       geometry=gpd.points_from_xy(df2.e32num, df2.n32num), \
                       crs="EPSG:25832")

# %%
gdf.head()
# Out:
#                sl_nr                 name     e32      n32  gw_stockwerk  \
# messstelle_id
# 32505929       67530  UWB-Ddorf 01285      343064  5678019           1.0
# 10446746       51044  60GP012303           292077  5645349           NaN
# 87005323       51070  58BP024606           287141  5684635           NaN
# 80000290       68442  Krinsend 0079 neu    309490  5678060           1.0
# 86583852       68518  WG102GM93-3          316741  5680237           NaN
#
#               grundstueck gemeinde_id gwhorizont_id      gwhorizont  \
# messstelle_id
# 32505929                     05111000           NaN             NaN
# 10446746           privat    NL000882             5  Zwischenmittel
# 87005323           privat    NL001640            6D  Neurather Sand
# 80000290                     05166024           NaN             NaN
# 86583852           privat    05166032           NaN             NaN
#
#               gwleiter_id  ... sumpfrohrlaenge_cm ausbaudurchmesser_mm  \
# messstelle_id              ...
# 32505929              NaN  ...                NaN                  NaN
# 10446746              NaN  ...                NaN                  NaN
# 87005323              NaN  ...              300.0                  NaN
# 80000290              NaN  ...                NaN                  NaN
# 86583852              NaN  ...                NaN                 80.0
#
#               historischer_ruhe_wsp einbaulaenge_cm oberkante_filter_cm  \
# messstelle_id
# 32505929                        NaN             NaN                 NaN
# 10446746                        NaN         16893.0             -3333.0
# 87005323                        NaN         32667.0            -29083.0
# 80000290                        NaN          1517.0              4832.0
# 86583852                        NaN          5400.0              1413.0
#
#               unterkante_filter_cm genau     n32num    e32num  \
# messstelle_id
# 32505929                       NaN   1.0  5678019.0  343064.0
# 10446746                   -3533.0   1.0  5645349.0  292077.0
# 87005323                  -29583.0   1.0  5684635.0  287141.0
# 80000290                    4832.0   1.0  5678060.0  309490.0
# 86583852                    1213.0   1.0  5680237.0  316741.0
#
#                                      geometry
# messstelle_id
# 32505929       POINT (343064.000 5678019.000)
# 10446746       POINT (292077.000 5645349.000)
# 87005323       POINT (287141.000 5684635.000)
# 80000290       POINT (309490.000 5678060.000)
# 86583852       POINT (316741.000 5680237.000)
#
# [5 rows x 42 columns]

# %%
gdf.to_file("GW_Stations.gpkg", layer='GW Stations', driver="GPKG")
